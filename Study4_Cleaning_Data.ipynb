# %%
import pandas as pd

# %%
df = pd.read_csv("./Study4.csv")
df.columns.values
# Out:
# array(['PID', 'q1', 'q1ans', 'q2', 'q2ans', 'q3', 'q3ans', 'q4', 'q4ans',
#        'q5', 'q5ans', 'q6', 'q6ans', 'q7', 'q7ans', 'q8', 'q8ans', 'q9',
#        'q9ans', 'q10', 'q10ans', 'q11', 'q11ans', 'q12', 'q12ans', 'q13',
#        'q13ans', 'q14', 'q14ans', 'q15', 'q16', 'q16ans', 'q17', 'q17ans',
#        'q18', 'q18ans', 'q19', 'q19ans', 'q20', 'q20ans', 'q21', 'q21ans',
#        'q22', 'q22ans', 'q23', 'q23ans', 'q24', 'q24ans', 'q25', 'q25ans',
#        'q26', 'q26ans', 'q27', 'q27ans', 'q28', 'q28ans', 'q29', 'q29ans',
#        'q30', 'q30ans', 'q31', 'q31ans', 'q32', 'q32ans', 'q33', 'q33ans',
#        'q34', 'q34ans', 'q35', 'q35ans', 'q36', 'q36ans', 'q37', 'q37ans',
#        'q38', 'q38ans', 'q39', 'q39ans', 'q40', 'q40ans',
#        'A_mentaldemand', 'A_boredom', 'B_mentaldemand', 'B_boredom',
#        'attencheck', 'self-admit', 'nfc_2', 'nfc_6', 'nfc_10', 'nfc_11',
#        'nfc_13', 'nfc_14', 'nfc_15', 'nfc_18', 'nfc_1', 'nfc_3', 'nfc_4',
# ...

# %%
df
# Out:
#      PID      q1      q1ans      q2    q2ans      q3      q3ans      q4  \
# 0      1  DECK A             DECK B  correct  DECK A             DECK A
# 1      2  DECK A             DECK B  correct  DECK B    correct  DECK A
# 2      3  DECK A             DECK A           DECK B    correct  DECK B
# 3      4  DECK B    correct  DECK A           DECK A             DECK A
# 4      5  DECK A             DECK A           DECK B  incorrect  DECK B
# ..   ...     ...        ...     ...      ...     ...        ...     ...
# 108  154  DECK A             DECK A           DECK B  incorrect  DECK B
# 109  155  DECK B  incorrect  DECK A           DECK B    correct  DECK B
# 110  156  DECK A             DECK A           DECK B    correct  DECK B
# 111  158  DECK A             DECK B  correct  DECK A             DECK B
# 112  160  DECK A             DECK A           DECK A             DECK B
#
#          q4ans      q5  ... nfc_16 nfc_17 Bps_1 Bps_2 Bps_3 Bps_4 Bps_5 Bps_6  \
# ...

# %%
df.drop(["A_mentaldemand", "A_boredom", "B_mentaldemand", "B_boredom"], axis=1, inplace=True)

# %%
df.drop(["Bps_1", "Bps_2", "Bps_3", "Bps_4", "Bps_5", "Bps_6", "Bps_7", "Bps_8"], axis=1, inplace=True)

# %%
df.columns.values
# Out:
# array(['PID', 'q1', 'q1ans', 'q2', 'q2ans', 'q3', 'q3ans', 'q4', 'q4ans',
#        'q5', 'q5ans', 'q6', 'q6ans', 'q7', 'q7ans', 'q8', 'q8ans', 'q9',
#        'q9ans', 'q10', 'q10ans', 'q11', 'q11ans', 'q12', 'q12ans', 'q13',
#        'q13ans', 'q14', 'q14ans', 'q15', 'q16', 'q16ans', 'q17', 'q17ans',
#        'q18', 'q18ans', 'q19', 'q19ans', 'q20', 'q20ans', 'q21', 'q21ans',
#        'q22', 'q22ans', 'q23', 'q23ans', 'q24', 'q24ans', 'q25', 'q25ans',
#        'q26', 'q26ans', 'q27', 'q27ans', 'q28', 'q28ans', 'q29', 'q29ans',
#        'q30', 'q30ans', 'q31', 'q31ans', 'q32', 'q32ans', 'q33', 'q33ans',
#        'q34', 'q34ans', 'q35', 'q35ans', 'q36', 'q36ans', 'q37', 'q37ans',
#        'q38', 'q38ans', 'q39', 'q39ans', 'q40', 'q40ans', 'attencheck',
#        'self-admit', 'nfc_2', 'nfc_6', 'nfc_10', 'nfc_11', 'nfc_13',
#        'nfc_14', 'nfc_15', 'nfc_18', 'nfc_1', 'nfc_3', 'nfc_4', 'nfc_5',
#        'nfc_7', 'nfc_9', 'nfc_8', 'nfc_12', 'nfc_16', 'nfc_17'],
#       dtype=object)

# %%
df["attencheck"].value_counts()
# Out:
# attencheck
# Blue     99
# Green    13
#           1
# Name: count, dtype: int64

# %%
df = df.drop(df[df["attencheck"] == "Green"].index)

# %%
df["attencheck"].value_counts()
# Out:
# attencheck
# Blue    99
#          1
# Name: count, dtype: int64

# %%
df["self-admit"].value_counts()
# Out:
# self-admit
# No     74
# Yes    26
# Name: count, dtype: int64

# %%
df = df.drop(df[df["self-admit"] == "Yes"].index)

# %%
df["self-admit"].value_counts()
# Out:
# self-admit
# No    74
# Name: count, dtype: int64

# %%
df.columns.values
# Out:
# array(['PID', 'q1', 'q1ans', 'q2', 'q2ans', 'q3', 'q3ans', 'q4', 'q4ans',
#        'q5', 'q5ans', 'q6', 'q6ans', 'q7', 'q7ans', 'q8', 'q8ans', 'q9',
#        'q9ans', 'q10', 'q10ans', 'q11', 'q11ans', 'q12', 'q12ans', 'q13',
#        'q13ans', 'q14', 'q14ans', 'q15', 'q16', 'q16ans', 'q17', 'q17ans',
#        'q18', 'q18ans', 'q19', 'q19ans', 'q20', 'q20ans', 'q21', 'q21ans',
#        'q22', 'q22ans', 'q23', 'q23ans', 'q24', 'q24ans', 'q25', 'q25ans',
#        'q26', 'q26ans', 'q27', 'q27ans', 'q28', 'q28ans', 'q29', 'q29ans',
#        'q30', 'q30ans', 'q31', 'q31ans', 'q32', 'q32ans', 'q33', 'q33ans',
#        'q34', 'q34ans', 'q35', 'q35ans', 'q36', 'q36ans', 'q37', 'q37ans',
#        'q38', 'q38ans', 'q39', 'q39ans', 'q40', 'q40ans', 'attencheck',
#        'self-admit', 'nfc_2', 'nfc_6', 'nfc_10', 'nfc_11', 'nfc_13',
#        'nfc_14', 'nfc_15', 'nfc_18', 'nfc_1', 'nfc_3', 'nfc_4', 'nfc_5',
#        'nfc_7', 'nfc_9', 'nfc_8', 'nfc_12', 'nfc_16', 'nfc_17'],
#       dtype=object)

# %%
df
# Out:
#      PID      q1      q1ans      q2      q2ans      q3      q3ans      q4  \
# 3      4  DECK B    correct  DECK A             DECK A             DECK A
# 5      6  DECK A             DECK A             DECK B  incorrect  DECK B
# 6      7  DECK A             DECK A             DECK B          0  DECK B
# 7      8  DECK A             DECK A             DECK B    correct  DECK B
# 8      9  DECK B    correct  DECK B  incorrect  DECK A             DECK A
# ..   ...     ...        ...     ...        ...     ...        ...     ...
# 103  146  DECK A             DECK B    correct  DECK A             DECK A
# 104  149  DECK A             DECK B    correct  DECK A             DECK B
# 105  150  DECK A             DECK B    correct  DECK B    correct  DECK B
# 106  151  DECK A             DECK B  incorrect  DECK A             DECK A
# 109  155  DECK B  incorrect  DECK A             DECK B    correct  DECK B
#
#          q4ans      q5  ... nfc_1 nfc_3 nfc_4 nfc_5 nfc_7 nfc_9 nfc_8 nfc_12  \
# ...
