# %%
import pandas as pd

# %%
df = pd.read_csv("./Study5.csv")

# %%
df
# Out:
#      PID      t1      t1ans      t2      t2ans      t3      t3ans      t4  \
# 0      1  DECK A             DECK B    correct  DECK A             DECK A
# 1      2  DECK A             DECK A             DECK A             DECK A
# 2      3  DECK A             DECK B    correct  DECK A             DECK A
# 3      4  DECK A             DECK B    correct  DECK A             DECK B
# 4      5  DECK B  incorrect  DECK B  incorrect  DECK A             DECK A
# ..   ...     ...        ...     ...        ...     ...        ...     ...
# 189  194  DECK A             DECK B  incorrect  DECK A             DECK B
# 190  195  DECK A             DECK A             DECK B  incorrect  DECK A
# 191  196  DECK A             DECK B  incorrect  DECK A             DECK B
# 192  197  DECK A             DECK B    correct  DECK B    correct  DECK B
# 193  198  DECK A             DECK B    correct  DECK A             DECK A
#
#        t4ans      t5  ... me_14 me_15 me_16 me_2 me_7 me_8 me_10 me_13 me_17  \
# ...

# %%
df.columns.values
# Out:
# array(['PID', 't1', 't1ans', 't2', 't2ans', 't3', 't3ans', 't4', 't4ans',
#        't5', 't5ans', 't6', 't6ans', 't7', 't7ans', 't8', 't8ans', 't9',
#        't9ans', 't10', 't10ans', 't11', 't11ans', 't12', 't12ans', 't13',
#        't13ans', 't14', 't14ans', 't15', 't15ans', 't16', 't16ans', 't17',
#        't17ans', 't18', 't18ans', 't19', 't19ans', 't20', 't20ans', 't21',
#        't21ans', 't22', 't22ans', 't23', 't23ans', 't24', 't24ans', 't25',
#        't25ans', 't26', 't26ans', 't27', 't27ans', 't28', 't28ans', 't29',
#        't29ans', 't30', 't30ans', 't31', 't31ans', 't32', 't32ans', 't33',
#        't33ans', 't34', 't34ans', 't35', 't36ans', 't36', 't36ans.1',
#        't37', 't37ans', 't38', 't38ans', 't39', 't39ans', 't40', 't40ans',
#        't41', 't41ans', 'checkadmit', 'A_mentaldemand', 'A_boredom',
#        'B_mentaldemand', 'B_boredom', 'checkcolor', 'nfc_2', 'nfc_6',
#        'nfc_10', 'nfc_11', 'nfc_13', 'nfc_14', 'nfc_15', 'nfc_18',
# ...

# %%
df.drop(["A_mentaldemand", "A_boredom", "B_mentaldemand", "B_boredom"], axis=1, inplace=True)

# %%
df.drop(["Bps_1", "Bps_2", "Bps_3", "Bps_5", "Bps_6", "Bps_7", "Bps_8", "me_1", 
         "me_2", "me_3", "me_4", "me_5", "me_6", "me_7", "me_8", "me_9", "me_10",
         "me_11", "me_12", "me_13", "me_14", "me_15", "me_16", "me_17", "me_18"], axis=1, inplace=True)

# %%
df.columns.values
# Out:
# array(['PID', 't1', 't1ans', 't2', 't2ans', 't3', 't3ans', 't4', 't4ans',
#        't5', 't5ans', 't6', 't6ans', 't7', 't7ans', 't8', 't8ans', 't9',
#        't9ans', 't10', 't10ans', 't11', 't11ans', 't12', 't12ans', 't13',
#        't13ans', 't14', 't14ans', 't15', 't15ans', 't16', 't16ans', 't17',
#        't17ans', 't18', 't18ans', 't19', 't19ans', 't20', 't20ans', 't21',
#        't21ans', 't22', 't22ans', 't23', 't23ans', 't24', 't24ans', 't25',
#        't25ans', 't26', 't26ans', 't27', 't27ans', 't28', 't28ans', 't29',
#        't29ans', 't30', 't30ans', 't31', 't31ans', 't32', 't32ans', 't33',
#        't33ans', 't34', 't34ans', 't35', 't36ans', 't36', 't36ans.1',
#        't37', 't37ans', 't38', 't38ans', 't39', 't39ans', 't40', 't40ans',
#        't41', 't41ans', 'checkadmit', 'checkcolor', 'nfc_2', 'nfc_6',
#        'nfc_10', 'nfc_11', 'nfc_13', 'nfc_14', 'nfc_15', 'nfc_18',
#        'nfc_1', 'nfc_3', 'nfc_4', 'nfc_5', 'nfc_7', 'nfc_9', 'nfc_8',
# ...

# %%
df["checkadmit"].value_counts()
# Out:
# checkadmit
# No     161
# Yes     33
# Name: count, dtype: int64

# %%
df = df.drop(df[df["checkadmit"] == "Yes"].index)

# %%
df["checkadmit"].value_counts()
# Out:
# checkadmit
# No    161
# Name: count, dtype: int64

# %%
df["checkcolor"].value_counts()
# Out:
# checkcolor
# Blue     154
# Green      7
# Name: count, dtype: int64

# %%
df = df.drop(df[df["checkcolor"] == "Green"].index)

# %%
df["checkcolor"].value_counts()
# Out:
# checkcolor
# Blue    154
# Name: count, dtype: int64

# %%
df
# Out:
#      PID      t1      t1ans      t2      t2ans      t3      t3ans      t4  \
# 1      2  DECK A             DECK A             DECK A             DECK A
# 3      4  DECK A             DECK B    correct  DECK A             DECK B
# 4      5  DECK B  incorrect  DECK B  incorrect  DECK A             DECK A
# 6      7  DECK A             DECK A             DECK A             DECK A
# 7      8  DECK B  incorrect  DECK B  incorrect  DECK A             DECK A
# ..   ...     ...        ...     ...        ...     ...        ...     ...
# 188  193  DECK A             DECK B  incorrect  DECK A             DECK A
# 189  194  DECK A             DECK B  incorrect  DECK A             DECK B
# 190  195  DECK A             DECK A             DECK B  incorrect  DECK A
# 191  196  DECK A             DECK B  incorrect  DECK A             DECK B
# 192  197  DECK A             DECK B    correct  DECK B    correct  DECK B
#
#        t4ans      t5  ... nfc_3 nfc_4 nfc_5 nfc_7 nfc_9 nfc_8 nfc_12 nfc_16  \
# ...
